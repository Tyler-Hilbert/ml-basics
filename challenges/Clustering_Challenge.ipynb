# %% [markdown]
# # Read Data

# %%
import pandas as pd
df = pd.read_csv('data/clusters.csv')
df
# Out:
#             A         B         C
# 0   -0.087492  0.398000  0.014275
# 1   -1.071705 -0.546473  0.072424
# 2    2.747075  2.012649  3.083964
# 3    3.217913  2.213772  4.260312
# 4   -0.607273  0.793914 -0.516091
# ..        ...       ...       ...
# 995  1.035455  1.916280  1.535641
# 996  3.479744  3.747277  3.038687
# 997  2.422571  1.771780  1.729732
# 998 -0.237440 -0.029278  0.077298
# 999  2.402302  2.166136  2.263434
#
# [1000 rows x 3 columns]

# %%
df.describe()
# Out:
#                  A            B            C
# count  1000.000000  1000.000000  1000.000000
# mean      1.513081     1.520776     1.498351
# std       1.250841     1.247587     1.267040
# min      -1.649121    -1.631006    -1.921651
# 25%       0.542161     0.561720     0.483172
# 50%       1.520402     1.526202     1.466841
# 75%       2.483222     2.505169     2.485410
# max       4.497581     4.442727     4.678731

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.plot3D(df.A, df.B, df.C, '.')
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.plot3D(df.A, df.B, df.C, '.')
ax.view_init(azim=45, elev=30)
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.plot3D(df.A, df.B, df.C, '.')
ax.view_init(azim=90, elev=30)
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.plot3D(df.A, df.B, df.C, '.')
ax.view_init(azim=0, elev=90)
plt.show()

# %% [markdown]
# I'm not finishing this challenge as it is clearly a bad dataset for a clustering algorithm.
